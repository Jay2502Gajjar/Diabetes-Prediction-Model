# %% [markdown]
# Importing the dependencies

# %%
import numpy as np;
import pandas as pd;
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm #the model used
from sklearn.metrics import accuracy_score

# %% [markdown]
# Data Collection and Analysis

# %%
dd =  pd.read_csv('C:/ML/diabetes.csv')

# %%
dd.head()

# %%
dd.shape
dd.describe()

# %%
dd['Outcome'].value_counts()

# %% [markdown]
# 0--> Non diabetic
#
# 1--> Diabetic

# %%
dd.groupby('Outcome').mean()

# %%
#seperating the data and labels

x =  dd.drop(columns = 'Outcome',axis = 1)
y = dd['Outcome']

# %%
print(x)

# %%
print(y)

# %% [markdown]
# Data Standardization

# %%
sca = StandardScaler()

# %%
x_scaled = sca.fit_transform(x)
x_scaled = pd.DataFrame(x_scaled, columns=sca.feature_names_in_)

# %%
x = x_scaled

y = dd['Outcome']

# %% [markdown]
# Split into train and test

# %%
x_train, x_test , y_train , y_test = train_test_split(x,y,test_size = 0.2,stratify = y,random_state = 2)

# %%
print(x.shape,x_train.shape,x_test.shape)

# %% [markdown]
# Training

# %%
cf = svm.SVC(kernel ='linear')

# %%
cf.fit(x_train,y_train)

# %% [markdown]
# Evaluation of model

# %% [markdown]
# Accuracy Score

# %%
x_train_prediction = cf.predict(x_train)
train_data_acc = accuracy_score(x_train_prediction,y_train)

# %%
print('Accuracy score of the training data i: ',train_data_acc)

# %%
x_test_prediction = cf.predict(x_test)
test_data_acc = accuracy_score(x_test_prediction,y_test)

# %%
print('Accuracy score of the testing data : ',test_data_acc)

# %% [markdown]
# Making a predictive system

# %%
input_data = (0,137,40,35,168,43.1,2.288,33)


#changing the input_data to numpyarray
input_data_as_numpy_array = np.asarray(input_data)

#reshape the array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

#standardize the input data
std_data = sca.transform(input_data_reshaped)
print(std_data)

prediction = cf.predict(std_data)
print(prediction)
